# %% [markdown]
# <a href="https://colab.research.google.com/github/mmaia2022/UFRN_BIB/blob/main/ufrn_bib_dia_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dados_emprestimos = pd.DataFrame()

# %%
import pandas as pd
dados_emprestimos = pd.read_csv('/content/sample_data/dados_emprestimos.csv')
dados_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario             id_exemplar  colecao            biblioteca                                                                                status_material  localizacao  classe_cdu
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO           195347       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba  REGULAR          640          Ciências aplicadas.                       1
# ...

# %%
dados_emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
# Alterando colunas data_emprestimos e data_devolucao para data em formato do Brasil dd/mm/aaaa do dataframe dados_emprestimos.csv


# Converter as colunas para datetime
dados_emprestimos['data_emprestimo'] = pd.to_datetime(dados_emprestimos['data_emprestimo'])
dados_emprestimos['data_devolucao'] = pd.to_datetime(dados_emprestimos['data_devolucao'])
dados_emprestimos['data_renovacao'] = pd.to_datetime(dados_emprestimos['data_renovacao'])


# Formatar as datas para dd/mm/aaaa
dados_emprestimos['data_emprestimo'] = dados_emprestimos['data_emprestimo'].dt.strftime('%d/%m/%Y')
dados_emprestimos['data_devolucao'] = dados_emprestimos['data_devolucao'].dt.strftime('%d/%m/%Y')
dados_emprestimos['data_renovacao'] = dados_emprestimos['data_renovacao'].dt.strftime('%d/%m/%Y')


dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras data_renovacao data_emprestimo data_devolucao  \
# 0         709684       L095049            NaN      04/01/2010     05/01/2010
# 1         709685       L167050            NaN      04/01/2010     12/01/2010
# 2         709686    2006017618     26/01/2010      04/01/2010     25/02/2010
# 3         709687       L184117     18/01/2010      04/01/2010     03/02/2010
# 4         709688    2007027500     19/01/2010      04/01/2010     03/02/2010
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
# 3        2.007211e+08      ALUNO DE GRADUAÇÃO       131639  Acervo Circulante
# 4        2.009046e+09      ALUNO DE GRADUAÇÃO       225646  Acervo Circulante
#
# ...

# %%
# Alterando colunas data_emprestimos e data_devolucao para data em formato do Brasil somente ano

import pandas as pd
dados_emprestimos = pd.DataFrame()
dados_emprestimos = pd.read_csv('/content/sample_data/dados_emprestimos.csv')
dados_emprestimos.value_counts()
dados_emprestimos


# Converter as colunas para datetime
dados_emprestimos['data_emprestimo'] = pd.to_datetime(dados_emprestimos['data_emprestimo'])
dados_emprestimos['data_devolucao'] = pd.to_datetime(dados_emprestimos['data_devolucao'])
dados_emprestimos['data_renovacao'] = pd.to_datetime(dados_emprestimos['data_renovacao'])


# Extrair somente o ano e formatar as datas
dados_emprestimos['data_emprestimo'] = dados_emprestimos['data_emprestimo'].dt.year
dados_emprestimos['data_devolucao'] = dados_emprestimos['data_devolucao'].dt.year
dados_emprestimos['data_renovacao'] = dados_emprestimos['data_renovacao'].dt.year

dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras  data_renovacao  data_emprestimo  \
# 0         709684       L095049             NaN             2010
# 1         709685       L167050             NaN             2010
# 2         709686    2006017618          2010.0             2010
# 3         709687       L184117          2010.0             2010
# 4         709688    2007027500          2010.0             2010
#
#    data_devolucao  matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0          2010.0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259
# 1          2010.0        2.008023e+09      ALUNO DE GRADUAÇÃO        70865
# 2          2010.0        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347
# 3          2010.0        2.007211e+08      ALUNO DE GRADUAÇÃO       131639
# 4          2010.0        2.009046e+09      ALUNO DE GRADUAÇÃO       225646
#
#              colecao                                         biblioteca  \
# ...

# %%
# Transformando a coluna matricula_ou_siape em formato string

# Transformar a coluna matricula_ou_siape em formato string
dados_emprestimos['matricula_ou_siape'] = dados_emprestimos['matricula_ou_siape'].astype(str)

# %%
dados_emprestimos.head()
# Out:
#    id_emprestimo codigo_barras  data_renovacao  data_emprestimo  \
# 0         709684       L095049             NaN             2010
# 1         709685       L167050             NaN             2010
# 2         709686    2006017618          2010.0             2010
# 3         709687       L184117          2010.0             2010
# 4         709688    2007027500          2010.0             2010
#
#    data_devolucao matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0          2010.0       2008023265.0      ALUNO DE GRADUAÇÃO        13259
# 1          2010.0       2008023265.0      ALUNO DE GRADUAÇÃO        70865
# 2          2010.0       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO       195347
# 3          2010.0        200721119.0      ALUNO DE GRADUAÇÃO       131639
# 4          2010.0       2009045971.0      ALUNO DE GRADUAÇÃO       225646
#
#              colecao                                         biblioteca  \
# ...

# %%
dados_emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 1644989       10170408    2012043113  2017/11/07 09:38:06.054000000
# 1644990       10170412    2012038934  2017/11/07 09:38:06.033000000
# 1644991       10170416    2013071958  2017/11/07 09:38:06.012000000
# 1644992       10170420    2013003412                            NaN
# 1644993       10170424    2011033197                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
# Agrupando por ano e contando pela coluna id_exemplar

emprestimos_por_ano = dados_emprestimos.groupby('data_emprestimo')['id_exemplar'].count()
emprestimos_por_ano
# Out:
# data_emprestimo
# 2010    161394
# 2011    196390
# 2012    221365
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: id_exemplar, dtype: int64

# %%
# Criando gráfico de barras verticais com eixo x=data_emprestimo e y=id_exemplar, com título 'Emprestimos de exemplares por ano - 2010 a 2020

import matplotlib.pyplot as plt

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))  # Ajustar o tamanho do gráfico
plt.bar(emprestimos_por_ano.index, emprestimos_por_ano.values)
plt.xlabel('Ano do Empréstimo')
plt.ylabel('Número de Empréstimos')
plt.title('Empréstimos de Exemplares por Ano - 2010 a 2020')
plt.xticks(emprestimos_por_ano.index)  # Mostrar todos os anos no eixo x

plt.show()
